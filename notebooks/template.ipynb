# %%
# %load_ext dotenv
# %dotenv -v

# %%
import os
os.environ
# Out:
# environ{'XDG_SEAT_PATH': '/org/freedesktop/DisplayManager/Seat0',
#         'XDG_CONFIG_DIRS': '/etc/xdg/xdg-cinnamon:/etc/xdg',
#         'LANG': 'ru_RU.UTF-8',
#         'DISPLAY': ':0',
#         'SHLVL': '1',
#         'LOGNAME': 'dvp',
#         'LANGUAGE': 'ru',
#         'MANDATORY_PATH': '/usr/share/gconf/cinnamon.mandatory.path',
#         'XDG_VTNR': '7',
#         'USER': 'dvp',
#         'J2REDIR': '/usr/lib/jvm/java-8-oracle/jre',
#         'J2SDKDIR': '/usr/lib/jvm/java-8-oracle',
#         'XAUTHORITY': '/home/dvp/.Xauthority',
#         'QT_QPA_PLATFORMTHEME': 'qt5ct',
#         'XDG_GREETER_DATA_DIR': '/var/lib/lightdm-data/dvp',
#         'COLORTERM': 'truecolor',
#         'XDG_SESSION_ID': 'c3',
#         'JAVA_HOME': '/usr/lib/jvm/java-8-oracle',
#         'GNOME_TERMINAL_SCREEN': '/org/gnome/Terminal/screen/57766bb0_5f60_433c_a75a_e7763798a6fc',
#         'DESKTOP_SESSION': 'cinnamon',
#         'XDG_SESSION_DESKTOP': 'cinnamon',
# ...
